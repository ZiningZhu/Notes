# %%
# NAACL bib marker changing
import os
import numpy as np
import bibtexparser

# %%
f = open("naacl_bib_raw", "r")
bibfile = bibtexparser.loads(f.read())
f.close()

for i in range(len(bibfile.entries)):

    item = bibfile.entries[i]
    entry_dict = item
    #print entry_dict
    if len(entry_dict) < 1:
        continue
    key = item["ID"]

    author_str = item[u"author"]
    title_str = item[u"title"]

    first_author_last_name = author_str.split()[0].strip(",")
    title_first_word = title_str.split()[0]
    new_key = first_author_last_name + "2018" + title_first_word
    print new_key
    
    bibfile.entries[i]["ID"] = new_key
    
with open("naacl_bib_processed.bib", "w") as f:
    f.write(bibtexparser.dumps(bibfile))

print "Done"
# Out:
# Wang2018Label-Aware
# Xu2018Neural
# Gupta2018Joint
# Cotterell2018A
# Kann2018Fortification
# Passban2018Improving
# Tran2018Parsing
# Anastasopoulos2018Tied
# Gillick2018Please
# Jo2018Attentive
# Ziai2018Automatic
# Rao2018Dear
# Dai2018Improving
# Juraska2018A
# Watanabe2018A
# Bosselut2018Discourse-Aware
# Fu2018Natural
# Ma2018Query
# Kriz2018Simplification
# Elsahar2018Zero-Shot
# Amorim2018Automated
# Bhagavatula2018Content-Based
# Khashabi2018Looking
# Farag2018Neural
# Grangier2018QuickEdit:
# Sen2018Tempo-Lexical
# Rei2018Zero-Shot
# Stathopoulos2018Variable
# K2018Learning
# Cocos2018Comparing
# Nguyen2018Improving
# Gu2018Universal
# Edunov2018Classical
# Benton2018Deep
# Zeng2018Microblog
# Habernal2018Before
# Wang2018Scene
# Kiela2018Learning
# Pezzelle2018Comparatives,
# Chao2018Being
# Issa2018Abstract
# Petroni2018attr2vec:
# Jana2018Can
# Rosenfeld2018Deep
# Chang2018Distributional
# Chinnappa2018Mining
# Ishihara2018Neural
# Vuli{\'{c}}2018Post-Specialisation:
# Pagliardini2018Unsupervised
# Liu2018Learning
# Duan2018Learning
# Zhou2018Relevant
# Akhtar2018Solving
# Marasovi{\'{c}}2018SRL4ORL:
# Junczys-Dowmunt2018Approaching
# Upadhyay2018Robust
# Xie2018Noising
# Sachan2018Self-Training
# Talmor2018The
# Liang2018A
# Kamila2018Fine-Grained
# Torabi2018Querying
# Sulem2018Semantic
# Amplayo2018Entity
# Grusky2018Newsroom:
# Richardson2018Polyglot
# Rudinger2018Neural
# An2018Accurate
# Yanaka2018Acquisition
# Mohtarami2018Automatic
# Yang2018Collective
# Kolyvakis2018DeepAlignment:
# Gao2018Efficient
# Thorne2018FEVER:
# Su2018Global
# Cheng2018Implicit
# Ning2018Improving
# Moon2018Multimodal
# Katiyar2018Nested
# Verga2018Simultaneously
# Stanovsky2018Supervised
# Gong2018Embedding
# Bjerva2018From
# Keith2018Monte
# Lin2018Neural
# Buys2018Neural
# Zalmout2018Noise-Robust
# Liu2018Parsing
# Yasunaga2018Robust
# Bhat2018Universal
# Gaddy2018What's
# Rios2018Deep
# Jiang2018Learning
# Durmus2018Exploring
# Wiegand2018Inducing
# Prabhakaran2018Author
# Nguyen2018Comparing
# Gupta2018Deep
# Hao2018Lessons
# Mullenbach2018Explainable
# Williams2018A
# Washio2018Filling
# Vuli{\'{c}}2018Specialising
# Damonte2018Cross-Lingual
# Schuster2018Sentences
# Szubert2018A
# Kasai2018End-to-End
# Gulordava2018Colorless
# Yu2018Diverse
# L{\'o}pez2018Early
# Chen2018Multinomial
# Ziser2018Pivot
# Wu2018Reinforced
# Huang2018Tensor
# Tran2018The
# Chen2018Combining
# Shen2018Dense
# Bawden2018Evaluating
# Post2018Fast
# Zhang2018Guiding
# Liu2018Handling
# Yang2018Improving
# Zaremoodi2018Neural
# Miculicich2018Self-Attentive
# Li2018Target
# Bergmanis2018Context
# Aguilar2018Modeling
# Assylbekov2018Reusing
# Kulkarni2018Simple
# Matthews2018Using
# Ju2018A
# Ghaeini2018DR-BiLSTM:
# Cai2018KBGAN:
# Botschen2018Multimodal
# Peng2018Learning
# Vyas2018Identifying
# Perez-Beltrachini2018Bootstrapping
# Zhang2018SHAPED:
# Nema2018Generating
# Suster2018CliCR:
# Tang2018Learning
# Yoon2018Learning
# Chung2018Supervised
# Dalvi2018Tracking
# Jin2018Combining
# Pryzant2018Deconfounded
# Chambers2018Detecting
# Card2018The
# Kang2018A
# Celikyilmaz2018Deep
# Zhang2018Encoding
# Zopf2018Estimating
# Krishna2018Generating
# Chen2018Generative
# Kamigaito2018Higher-Order
# Zhou2018Neural
# Sakaue2018Provable
# Narayan2018Ranking
# Handler2018Relational
# Gorinski2018What's
# Zopf2018Which
# Park2018A
# Sandbank2018Detecting
# Jiang2018Learning
# Chen2018Variational
# Cheng2018Inducing
# Radhakrishnan2018ELDEN:
# Ye2018Interpretable
# Li2018Delete,
# Iyyer2018Adversarial
# Kenyon-Dean2018Sentiment
# Augenstein2018Multi-Task
# Buechel2018Word
# Ding2018Human
# Habernal2018The
# Levitan2018Linguistic
# Fried2018Unified
# Subramanian2018Hierarchical
# Sanchez2018Behavior
# Berzak2018Assessing
# Zhan2018Comparing
# Amiri2018Spotting
# Cole2018The
# Barrett2018Unsupervised
# Ma2018Challenging
# Wu2018Dialog
# Liu2018Dialogue
# Xu2018LSDSCC:
# Rios2018EMR
# Wendlandt2018Factors
# Liu2018Mining
# Liu2018Binarized
# Hazarika2018Conversational
# Su2018How
# Loukina2018Towards
# Monroe2018Generating
# Andreas2018Learning
# Wang2018Object
# Hessel2018Quantifying
# Azab2018Speaker
# Rajani2018Stacking
# Peters2018Deep
# Suhr2018Learning
# Clark2018Neural
# Chen2018Recurrent
# Hou2018Enhanced
# Rudinger2018Gender
# Zhao2018Gender
# Baly2018Integrating
# Rajendran2018Is
# Schulz2018Multi-Task
# Dhingra2018Neural
# Huang2018Automatic
# Li2018Guiding
# Su2018Natural
# Ghazvininejad2018Neural
# Novikova2018RankME:
# Vu2018Sentence
# Beigman2018A
# Srinivasan2018A
# Kulkarni2018An
# Gururangan2018Annotation
# Chen2018Humor
# Qian2018Leveraging
# Choshen2018Reference-less
# Rooshenas2018Training
# Stewart2018Si
# Vilares2018A
# K{\"o}per2018Analogies
# Lan2018Character-Based
# Vempala2018Determining
# Schlechtweg2018Diachronic
# Song2018Directional
# Glava{\v{s}}2018Discriminating
# Braune2018Evaluating
# Coates2018Frustratingly
# Nguyen2018Introducing
# Buljan2018Lexical
# Dingwall2018Mittens:
# Shwartz2018Olive
# Kashefi2018Semantic
# Paula2018Similarity
# R{\o}nning2018Sluice
# Schluter2018The
# Wang2018Transition-Based
# Kumar2018Knowledge-Enriched
# Maharjan2018Letting
# Hazarika2018Modeling
# Yadav2018Multi-Task
# Liu2018Recurrent
# Grundkiewicz2018Near
# Mohammed2018Strong
# Weise2018Looking
# Wang2018Modeling
# Wang2018A
# Plachouras2018A
# H{\"a}tty2018A
# Nguyen2018A
# Wu2018Cross-language
# Choubey2018Identifying
# Zhao2018Improve
# Nagesh2018Keep
# Ferguson2018Semi-Supervised
# Wen2018Structure
# Patel2018Syntactic
# Espinosa2018Syntactically
# Fern{\'a}ndez-Gonz{\'a}lez2018A
# Rama2018Are
# Wisniewski2018Automatically
# Yoshikawa2018Consistent
# Aufrant2018Exploiting
# Shi2018Improving
# Pasquer2018Towards
# Madhyastha2018Defoiling
# Cohn-Gordon2018Pragmatically
# Tan2018Object
# Kobayashi2018Contextual
# Sasaki2018Cross-Lingual
# Shaw2018Self-Attention
# Koshorek2018Text
# Li2018What's
# Apidianaki2018Automated
# Marcheggiani2018Exploiting
# Dalvi2018Incremental
# Vilar2018Learning
# Hasler2018Neural
# Poliak2018On
# Pourdamghani2018Using
# Qi2018When
# Cotterell2018Are
# Chen2018The
# Cotterell2018Unsupervised
# Salant2018Contextualized
# Michael2018Crowdsourcing
# Song2018Leveraging
# Wang2018Robust
# Dhingra2018Simple
# Yu2018TypeSQL:
# Jaech2018Community
# Chen2018Cross-Domain
# Volkova2018Predicting
# Cohan2018A
# Jain2018A
# Jiang2018Effective
# Mahata2018Key2Vec:
# Kaffee2018Learning
# Pasunuru2018Multi-Reward
# Peyrard2018Objective
# Honda2018Pruning
# Boudin2018Unsupervised
# Chaturvedi2018Where
# Barbieri2018Multimodal
# Lee2018Higher-Order
# Fern{\'a}ndez-Gonz{\'a}lez2018Non-Projective
# Karlekar2018Detecting
# Louis2018Deep
# Casanueva2018Feudal
# Robertson2018Evaluating
# Xiao2018Gated
# Huang2018Natural
# Chen2018Smaller
# Al2018Role-specific
# Goo2018Slot-Gated
# Gella2018An
# Manjunatha2018Learning
# Chandrasekaran2018Punny
# Dharmaretnam2018The
# Cirik2018Visual
# Rahgooy2018Visually
# Wang2018Watch,
# Amoia2018Scalable
# Shah2018Neural
# Kim2018A
# Gangadharaiah2018What
# Kang2018Data
# Shah2018Bootstrapping
# Ueffing2018Quality
# Yoon2018Atypical
# Mitcheltree2018Using
# laura2018SystemT:
# Ammar2018Construction
# Kreutzer2018Can
# Iglesias2018Accelerating
# Quinn2018Pieces
# Finley2018From
# Pivovarova2018Benchmarks
# Gaspers2018Selecting
# Goyal2018Fast
# Jha2018Bag
# Mathur2018Multi-lingual
# Niraula2018A
# Kollar2018The
# Mehrabani2018Practical
# Ambroselli2018Prediction
# Hopkinson2018Demand-Weighted
# Fiorini2018Personalized
# Elsafty2018Document-based
# Shin2018Alignment,
# Aedmaa2018Combining
# Seyffarth2018Verb
# Emami2018A
# Pierrejean2018Towards
# MacAvaney2018A
# Kameswara2018Learning
# Ezeani2018Igbo
# Lavrentovich2018Using
# Liu2018End-to-End
# Acharya2018Towards
# Deng2018Read
# Nangia2018ListOps:
# Kurosawa2018Japanese
# Shimanaka2018Metric
# Ramesh2018Neural
# Htut2018Training
# Vijay2018Corpus
# Tornblad2018Sensing
# Jindal2018Generating
# Schreiber2018NLP
# Tu2018Pay-Per-Request
# Finley2018An
# Singh2018CL
# Stab2018ArgumenText:
# Jaradat2018ClaimRank:
# Ruder2018360{\textdegree}
# Schneider2018DebugSL:
# Zhang2018ELISA-EDL:
# Maheshwari2018Entity
# Gokcen2018Madly
# Vu2018VnCoreNLP:
# Liang2018CNNs
# graham2018Generating
# Steele2018Vis-Eval
# Deleris2018Know
# Liu2018RiskFinder:
# Kim2018SMILEE:
# Deleris2018Decision
# Fang2018Sounding
# Done

# %%
dir(bi)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_entries_dict',
#  'comments',
#  'entries',
#  'entries_dict',
#  'entry_sort_key',
#  'expand_string',
#  'get_entry_dict',
#  'get_entry_list',
#  'load_common_strings',
#  'preambles',
#  'strings']
